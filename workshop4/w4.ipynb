# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas_datareader
# !pip install matplotlib
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\bobad\appdata\roaming\python\python39\site-packages (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas_datareader in c:\users\bobad\appdata\roaming\python\python39\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas_datareader) (1.4.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas>=0.23->pandas_datareader) (1.23.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas>=0.23->pandas_datareader) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.4)
# Requirement already satisfied: six>=1.5 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\bobad\appdata\roaming\python\python39\site-packages (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six in c:\users\bobad\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\users\bobad\appdata\roaming\python\python39\site-packages (0.13.2)
# Requirement already satisfied: scipy>=1.3 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from statsmodels) (1.9.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from statsmodels) (1.4.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from statsmodels) (1.23.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from packaging>=21.3->statsmodels) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bobad\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2021.1)
# Requirement already satisfied: six in c:\users\bobad\appdata\roaming\python\python39\site-packages (from patsy>=0.5.2->statsmodels) (1.15.0)

# %%
import pandas_datareader as pdr
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Getting price data and selecting adjusted price columns:
sprices = pdr.get_data_yahoo(['ALFAA.MX','^MXX'],start="01/01/2018", end="07/31/2022",interval="m")
sprices = sprices['Adj Close']

# Calculating returns:
sr = np.log(sprices) - np.log(sprices.shift(1))
# Deleting the first month with NAs:
sr=sr.dropna()
sr.columns=['ALFAA','MXX']

# %%
sr.plot.scatter(x='MXX', y='ALFAA',c='DarkBlue')
plt.show()

# %%
# Scatter plots can be misleading when ranges of X and Y are very different.
# In this case, Alfa had a very bad month in the COVID crisis with more than 60% loss!! 
# Then, we can re-do the scatter plot trying to make the X and Y axis using the same range of values 
plt.clf()
x=sr['MXX']
y = sr['ALFAA']
plt.scatter(x, y)
# Now I add the regression line:
b1,b0 = np.polyfit(x,y,1)
yfit = b0+b1*x

plt.plot(x, yfit,c="orange")

plt.xticks(np.arange(-0.50,0.5,0.1))
plt.xlabel("Market returns")
plt.ylabel("Alfa returns")

plt.show()

# %%
# Another faster way to plot a scatter and the regression line:
# I use the seaborn library:
import seaborn as sns
plt.clf()

sns.regplot(x, y)
plt.xticks(np.arange(-0.50,0.5,0.1))
plt.xlabel("Market returns")
plt.ylabel("Alfa returns")

plt.show()
# Out:
# C:\Users\bobad\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import statsmodels.api as sm
X = sm.add_constant(x)

mkmodel = sm.OLS(y,X).fit()
 
print(mkmodel.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ALFAA   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     28.66
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):           1.89e-06
# Time:                        23:32:34   Log-Likelihood:                 43.918
# No. Observations:                  55   AIC:                            -83.84
# Df Residuals:                      53   BIC:                            -79.82
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0077      0.015     -0.513      0.610      -0.038       0.022
# MXX            1.5370      0.287      5.353      0.000       0.961       2.113
# ==============================================================================
# Omnibus:                        9.500   Durbin-Watson:                   2.206
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               22.571
# Skew:                          -0.144   Prob(JB):                     1.26e-05
# Kurtosis:                       6.125   Cond. No.                         19.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
